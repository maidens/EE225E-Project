# %%
# Generate ground truth parameter map 
n = 12 # number of pixels in each dimension 
radius = sqrt(2.)/2. # half-side-length for rectangle -- adjusted such that area of rectangle matches area outside rectangle 
theta_map = convert(Array{Float64, 2}, [0.9 + 0.1*float( (x < radius) & (x > -radius) & (y < radius) & (y > -radius)) for x in linspace(-1, 1, n), y in linspace(-1, 1, n)])

using Plots
pyplot()
heatmap(theta_map, title="Ground truth parameter map")
# Out:
# [Plots.jl] Initializing backend: pyplot
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M25.8125 263.298
# L340.394 263.298
# L340.394 26.3183
# L25.8125 26.3183
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pa65e9c039d)" d="
# M25.8125 263.298
# ...

# %%
# Generate simulated trajectories of the simple dynamical system 
# 
#    x[t+1] = theta x[t] 
# 

N = 30 # time horizon 
function trajectories(theta)
    x = zeros(N)
    x[1] = 1
    for t=1:N-1
        x[t+1] = theta*x[t]
    end
    return x + 0.1*randn(size(x))
end

simulated_data = map(trajectories, theta_map)

plot([simulated_data[1, 1] simulated_data[round(Int, n/2), round(Int, n/2)]], ylim=(-0.2, 1.4), labels=["(x,y) = ( 1,  1); theta = 0.9" "(x,y) = (12, 12);theta = 1.0"])
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M34.7375 263.298
# L414.521 263.298
# L414.521 16.8313
# L34.7375 16.8313
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p2cdd4d33ea)" d="
# M34.7375 263.298
# ...

# %%
# perform Douglas-Rachford iteration for different values of the regularization parameter lambda 


using MATLAB

function ADMM_test(data, theta0, lambda::Float64, rho::Float64)
    
    function theta_step(data, theta, z, u)
        # data represents times series from a particular voxel 
        b = data[2:end]
        A = data[1:end-1]
        return (((1/rho)*A'*A + eye(size(A, 2)))\((1/rho)*A'*b + z - u))[1]
    end
    
    function prox_g(theta, z, u)
        return mxcall(:TV, 1, theta + u, lambda/rho)
    end
    
    function u_step(theta, z, u)  
        return u + theta - z
    end
    
    theta = map(y->1.0, data)
    z     = map(y->0.9, data)
    u     = map(y->0., data)
    
    # iterate ADMM until convergence, or until we reach max_iter iterations 
    max_iters = 400
    iterations = 0
    epsilon = 1e-5
    while ((iterations < max_iters) & (norm(theta - z) > epsilon ))
        theta = map(theta_step, data, theta, z, u) # this can be parallelized 
        z     = prox_g(theta, z, u)
        u     = map(u_step, theta, z, u) # this can be parallelized too 
        iterations += 1
    end
    println("iterations = ", iterations)
    
    return theta
end

# initialization for model parameter search 
theta0 = 0.95

# vector of regularization parameters to use 
lambdas = logspace(-2, 1, 11)

# Douglas-Rachford parameter 
rho = 1.0

# iterate through vector lambdas 
x_opt = zeros(Float64, size(simulated_data, 1), size(simulated_data, 2), length(lambdas))
for k=1:length(lambdas)
    println("====== ", k, " of ", length(lambdas), " ======")
    lambda = lambdas[k]
    println("lambda = ", lambda)
    x_opt[:, :, k] = ADMM_test(simulated_data, theta0, lambda, rho)
end
println("done")
# Out:
# ====== 1 of 11 ======
# lambda = 0.01
# A MATLAB session is open successfully
# iterations = 140
# ====== 2 of 11 ======
# lambda = 0.0199526231496888
# iterations = 158
# ====== 3 of 11 ======
# lambda = 0.039810717055349734
# iterations = 201
# ====== 4 of 11 ======
# lambda = 0.07943282347242814
# iterations = 226
# ====== 5 of 11 ======
# lambda = 0.15848931924611132
# iterations = 234
# ====== 6 of 11 ======
# lambda = 0.31622776601683794
# iterations = 236
# ====== 7 of 11 ======
# lambda = 0.6309573444801932
# iterations = 238
# ====== 8 of 11 ======
# lambda = 1.2589254117941673
# iterations = 238
# ====== 9 of 11 ======
# lambda = 2.51188643150958
# iterations = 238
# ====== 10 of 11 ======
# lambda = 5.011872336272722
# iterations = 238
# ====== 11 of 11 ======
# lambda = 10.0
# iterations = 238
# done

# %%
# compare estimate against ground truth to select regularization parameter lambda 
select_lambda = zeros(length(lambdas))
for k=1:length(lambdas)
    select_lambda[k] = norm(x_opt[:, :, k] - theta_map, 1)
end

index_lambda_opt = findmin(select_lambda)[2]
lambda_opt = lambdas[index_lambda_opt]
plot(lambdas, select_lambda, xaxis=:log10, xlabel="lambda", ylabel="l1 error", legend=false)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M44.3522 246.834
# L411.32 246.834
# L411.32 16.8312
# L44.3522 16.8312
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pc67f17860b)" d="
# M44.3522 246.834
# ...

# %%
# optimal value of lambda 
lambda_opt
# Out:
# 0.6309573444801932

# %%
# plot ground truth
heatmap(theta_map, title="ground truth")
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M25.8125 263.298
# L340.394 263.298
# L340.394 26.3183
# L25.8125 26.3183
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pa65e9c039d)" d="
# M25.8125 263.298
# ...

# %%
# plot estimated parameter map without regularization 
heatmap(x_opt[:, :, 1], title="Parameter map without regularization")
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M25.8125 263.298
# L340.394 263.298
# L340.394 26.3183
# L25.8125 26.3183
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pa65e9c039d)" d="
# M25.8125 263.298
# ...

# %%
# plot estimated parameter map with optimal regularization
heatmap(x_opt[:, :, index_lambda_opt], title="TV regularized parameter map")
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M25.8125 263.298
# L340.394 263.298
# L340.394 26.3183
# L25.8125 26.3183
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#pa65e9c039d)" d="
# M25.8125 263.298
# ...
