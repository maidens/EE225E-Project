# %%
function circ(x::Array{Float64, 1}, y::Array{Float64, 1}, diam::Float64, x0::Float64, y0::Float64)
    return [float((x-x0)^2 + (y-y0)^2 < (diam/2.)^2) for x in x, y in y]
end

function rect(x::Array{Float64, 1}, y::Array{Float64, 1}, Lx::Float64, Ly::Float64, x0::Float64, y0::Float64)
    return [float( abs(x-x0)<Lx/2 && abs(y-y0)<Ly/2 ) for x in x, y in y]
end

function face(x,y)
# FACE generates a face-shaped phantom

    # outline of face
    F = 0.8*circ(x, y, 20., 0., 0.); 

    # nose 
    F = F-0.4*rect(x, y, 1.5, 4., 0., 0.5); 

    # mouth
    F = F-0.4*rect(x, y, 10., 1.5, 0., 5.75); 

    # eyes
    F = F-0.4*circ(x, y, 3.5,  4., -4.25); 
    F = F-0.4*circ(x, y, 3.5, -4., -4.25); 

    # pupils 
    offset = 0.9; 
    F = F-0.4*circ(x, y, 1.,  4.-offset, -4.25+offset); 
    F = F-0.4*circ(x, y, 1., -4.+offset, -4.25+offset); 

    return F
end

function generate_kTRANS_map(x, y)
    F = 0.05*circ(x, y, 20., 0., 0.)
    return F
end

function generate_kPL_map(x, y)
    # nose
    F = rect(x, y, 1.5, 4., 0., 0.5)
    
    # mouth
    F = F+rect(x, y, 10., 1.5, 0., 5.75) 

    # eyes
    F = F+circ(x, y, 3.5,  4., -4.25) 
    F = F+circ(x, y, 3.5, -4., -4.25) 

    # pupils 
    offset = 0.7; 
    F = F-circ(x, y, 1.,  4.-offset, -4.25+offset) 
    F = F-circ(x, y, 1., -4.+offset, -4.25+offset)
    
    return 0.07*F
end;

# %%
# parameters for grid 
Wx = 25.6
Wy = 25.6
Nx = 256
Ny = 256

# generate space grid
x_itvl = collect(-Nx/2:Nx/2-1)/Nx * Wx
y_itvl = collect(-Ny/2:Ny/2-1)/Ny * Wy;

# %%
kTRANS_map = generate_kTRANS_map(x_itvl, y_itvl)
kPL_map    = generate_kPL_map(x_itvl, y_itvl);

# %%
using PyPlot

# %%
# ion()
fig = figure()
ax = fig[:add_subplot](111)
img = ax[:imshow](kTRANS_map'-kPL_map')
show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31afab4d0>)

# %%
function trajectories(kTRANS::Float64, kPL::Float64)
    # FUNCTION TRAJECTORIES computes trajectories of the model 
    
    N   = 30; 
    x0  = [0.; 0.]; 
    TR  = 2;
    R1P = 1./20; 
    R1L = 1./20;        
    
    gamma = 2.1430
    beta  = 3.4658
    A0    = 10.4105
    t0    = 3.2596
    
    params = [N, TR, R1P, R1L, gamma, beta, A0, t0]
    
    alphas = [30./180*pi*ones(1, N); 30./180*pi*ones(1, N)]
    
    t_input = 2*(1:N);
    u = A0*1000*(max( t_input - t0, zeros(size(t_input)))).^gamma.*exp(-(t_input - t0)/beta);
    
    A = [ -kPL-R1P   0  ;
             kPL   -R1L];  
         
    B = [kTRANS; 0]; 

    C = [1 0; 
         0 1]; 
       
    D = [0; 
         0]; 

    Ad = expm(TR*A)
    Bd = inv(A)*(Ad - eye(2))*B
    
    n = size(Ad, 1); 
    m = size(C, 1); 
    x = zeros(n, N); 
    y = zeros(m, N); 

    # compute state trajectories 
    x[:, 1] = x0; 
    for t=1:N-1
        x[:, t+1] = Ad * diagm(cos(alphas[:, t])) * x[:, t] + Bd * u[t];
    end
    # compute output trajectories 
    for t=1:N
        y[:, t] = C * diagm(sin(alphas[:, t])) * x[:, t] + D * u[t]; 
    end
    
    return (y, u'.*alphas[1, :], params)
end

# test trajectories function 
y_sim, u_sim, params = trajectories(0.05, 0.07);
# Out:
# 2x30 Array{Float64,2}:
#  0.0  0.0  196.271   1954.28   4639.8    …   41.584   28.8873   20.0189
#  0.0  0.0   13.8144   159.058   557.568     281.215  224.66    179.027

# %%
using Gadfly
using Colors 

berkeley_blue = RGB((1/256*[ 45.,  99., 127.])...)
berkeley_gold = RGB((1/256*[224., 158.,  25.])...);

# %%
function generate_simulated_data(Nxy, sigma)
    # Nxy number of samples in each spatial dimension 
    # sigma noise parameter 
    
    # parameters for grid 
    Wx = 25.6;
    Wy = 25.6;
    Nx = Nxy;
    Ny = Nxy;

    # generate space grid
    x_itvl = collect(-Nx/2:Nx/2-1)/Nx * Wx;
    y_itvl = collect(-Ny/2:Ny/2-1)/Ny * Wy;
    
    # generate parameter maps 
    kTRANS_map = generate_kTRANS_map(x_itvl, y_itvl)
    kPL_map    = generate_kPL_map(x_itvl, y_itvl);
    
    dims = size(trajectories(kTRANS_map[1, 1], kPL_map[1, 1])[1])
    
    return [trajectories(kTRANS_map[i, j], kPL_map[i, j])[1] + sigma*randn(dims) for i=1:Nx, j=1:Ny]; 
end

simulated_data = generate_simulated_data(32, 1000);

# %%
y_sim = simulated_data[17, 19]

Gadfly.plot(
    layer(x=2*(0:29), y=y_sim[1, :], Geom.point, Geom.line, Theme(default_color=berkeley_blue)), 
    layer(x=2*(0:29), y=y_sim[2, :], Geom.point, Geom.line, Theme(default_color=berkeley_gold)),
    Guide.XLabel("time from injection start (s)"), 
    Guide.YLabel("signal (au)"), 
)
# Out:
# Plot(...)

# %%
test = [maximum(simulated_data[i, j]) for i=1:32, j=1:32]
fig = figure()
ax = fig[:add_subplot](111)
img = ax[:imshow](test')
show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b111250>)

# %%
using Optim

# nonlinear least squares fit (i.e. maximum-likelihood fit, assuming a Gaussian noise model)
function nonlinear_least_squares_fit(y_sim)
    function obj(theta::Vector, y::Array{Float64, 2})
        return sum((y - (trajectories(theta[1], theta[2]))[1]).^2)
    end

    res = optimize(theta->obj(theta, y_sim), [0.05, 0.07])
    return res.minimum
end

@time nonlinear_least_squares_fit(y_sim)
# Out:
# 2-element Array{Float64,1}:
#  0.0474527
#  0.0681469

# %%
# linear least squares fit (see project report for details)
function linear_least_squares_fit(y, u, params)
    
    N   = round(Int, params[1])    
    TR  = params[2]
    R1P = params[3] + 0.02
    R1L = params[4] + 0.02
    
    P = y[1, :]
    L = y[2, :]
    
    P_dot = (P[2:end]-P[1:end-1])/TR 
    L_dot = (L[2:end]-L[1:end-1])/TR 
    
    P = y[1, 2:end]
    L = y[2, 2:end]
    
    M = [u'[2:end] -P'; zeros(N-1, 1) P']
    b = [P_dot+R1P*P'; L_dot+R1L*L']
    
    return M\b
end

@time linear_least_squares_fit(y_sim, u_sim, params)
# Out:
# 3.139603 seconds (4.52 M allocations: 215.778 MB, 3.59% gc time)
# 2x1 Array{Float64,2}:
#  0.0333039
#  0.029457

# %%
# generate simulated data 
simulated_data = generate_simulated_data(32, 2000); 

# compute parameter map using nonlinear least squares method
fit_parameter_map_nonlinear = map(nonlinear_least_squares_fit, simulated_data); 

# extract maps for individual parameters 
fit_kTRANS_map_32 = map(theta->theta[1], fit_parameter_map_nonlinear); 
fit_kPL_map_32    = map(theta->theta[2], fit_parameter_map_nonlinear);

# %%
# generate simulated data 
simulated_data = generate_simulated_data(32, 1000); 

# compute parameter map using linear least squares method ## SO MUCH FASTER! 
fit_parameter_map_linear = map(y->linear_least_squares_fit(y, u_sim, params), simulated_data); 

# extract maps for individual parameters 
fit_kTRANS_map_32 = map(theta->theta[1], fit_parameter_map_linear); 
fit_kPL_map_32    = map(theta->theta[2], fit_parameter_map_linear);

# %%
# plot kPL map
fig = figure()
ax = fig[:add_subplot](111)
img = ax[:imshow](fit_kPL_map_32')
img[:cmap] = ColorMap("summer")
img[:set_clim](vmin=0, vmax=0.15)
colorbar(img)
title("kPL 32 x 32")
savefig("kPL_32.png")
show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32679c910>)

# %%
# plot kTRANS map
fig = figure()
ax = fig[:add_subplot](111)
img = ax[:imshow](fit_kTRANS_map_32')
img[:cmap] = ColorMap("summer")
img[:set_clim](vmin=0, vmax=0.15)
colorbar(img)
title("kTRANS 32 x 32")
savefig("kTRANS_32.png")
show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3264ad1d0>)

# %%
# generate simulated data 
simulated_data = generate_simulated_data(2*32, 4*1000); 

# compute parameter map 
fit_parameter_map = map(nonlinear_least_squares_fit, simulated_data); 

# extract maps for individual parameters 
fit_kTRANS_map_64 = map(theta->theta[1], fit_parameter_map); 
fit_kPL_map_64    = map(theta->theta[2], fit_parameter_map);
# Out:
# LoadError: InterruptException:
# while loading In[17], in expression starting on line 5

# %%
# plot kPL map
fig = figure()
ax = fig[:add_subplot](111)
img = ax[:imshow](fit_kPL_map_64')
img[:cmap] = ColorMap("summer")
img[:set_clim](vmin=0, vmax=0.15)
colorbar(img)
title("kPL 64 x 64")
savefig("kPL_64.png")
show()
# Out:
# LoadError: UndefVarError: fit_kPL_map_64 not defined
# while loading In[18], in expression starting on line 4
#
#  in getindex at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:228
#  in pysequence_query at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:717
#  [inlined code] from /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:733
#  in pytype_query at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:762
#  in convert at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:782
#  in pycall at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:363
#  in call at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:372
#  in close_queued_figs at /Users/maidens/.julia/v0.4/PyPlot/src/PyPlot.jl:401

# %%
# plot kTRANS map
fig = figure()
ax = fig[:add_subplot](111)
img = ax[:imshow](fit_kTRANS_map_64')
img[:cmap] = ColorMap("summer")
img[:set_clim](vmin=0, vmax=0.15)
colorbar(img)
title("kTRANS 64 x 64")
savefig("kTRANS_64.png")
show()
# Out:
# LoadError: UndefVarError: fit_kTRANS_map_64 not defined
# while loading In[19], in expression starting on line 4
#
#  in getindex at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:228
#  in pysequence_query at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:717
#  [inlined code] from /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:733
#  in pytype_query at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:762
#  in convert at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:782
#  in pycall at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:363
#  in call at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:372
#  in close_queued_figs at /Users/maidens/.julia/v0.4/PyPlot/src/PyPlot.jl:401

# %%
# generate simulated data 
simulated_data = generate_simulated_data(4*32, 16*1000); 

# compute parameter map 
fit_parameter_map = map(nonlinear_least_squares_fit, simulated_data); 

# extract maps for individual parameters 
fit_kTRANS_map_128 = map(theta->theta[1], fit_parameter_map); 
fit_kPL_map_128    = map(theta->theta[2], fit_parameter_map);
# Out:
# LoadError: InterruptException:
# while loading In[20], in expression starting on line 5
#
#  in max at operators.jl:398
#  in trajectories at In[6]:20
#  in obj at In[11]:6
#  in anonymous at In[11]:9
#  in nelder_mead at /Users/maidens/.julia/v0.4/Optim/src/nelder_mead.jl:125
#  in optimize at /Users/maidens/.julia/v0.4/Optim/src/optimize.jl:508
#  in nonlinear_least_squares_fit at In[11]:9
#  in map_to! at abstractarray.jl:1260
#  in map at abstractarray.jl:1282

# %%
# plot kPL map
fig = figure()
ax = fig[:add_subplot](111)
img = ax[:imshow](fit_kPL_map_128')
img[:cmap] = ColorMap("summer")
img[:set_clim](vmin=0, vmax=0.15)
colorbar(img)
title("kPL 128 x 128")
savefig("kPL_128.png")
show()
# Out:
# LoadError: UndefVarError: fit_kPL_map_128 not defined
# while loading In[21], in expression starting on line 4
#
#  in getindex at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:228
#  in pysequence_query at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:717
#  [inlined code] from /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:733
#  in pytype_query at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:762
#  in convert at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:782
#  in pycall at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:363
#  in call at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:372
#  in close_queued_figs at /Users/maidens/.julia/v0.4/PyPlot/src/PyPlot.jl:401

# %%
# plot kTRANS map
fig = figure()
ax = fig[:add_subplot](111)
img = ax[:imshow](fit_kTRANS_map_128')
img[:cmap] = ColorMap("summer")
img[:set_clim](vmin=0, vmax=0.15)
colorbar(img)
title("kTRANS 128 x 128")
savefig("kTRANS_128.png")
show()
# Out:
# LoadError: UndefVarError: fit_kTRANS_map_128 not defined
# while loading In[22], in expression starting on line 4
#
#  in getindex at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:228
#  in pysequence_query at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:717
#  [inlined code] from /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:733
#  in pytype_query at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:762
#  in convert at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:782
#  in pycall at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:363
#  in call at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:372
#  in close_queued_figs at /Users/maidens/.julia/v0.4/PyPlot/src/PyPlot.jl:401

# %%
using MATLAB

function ADMM(simulated_data, theta0)
    
    rho = 1e-3
    
    function theta_step(y, theta, z, u)
        
        function obj(theta::Vector, y::Array{Float64, 2})
            return sum((y - trajectories(theta[1], theta[2])[1]).^2) + 0.5*rho*norm(theta - z + u)^2
        end

        res = optimize(theta->obj(theta, y), [0.05, 0.07], xtol=1e-2, iterations=50)
        return res.minimum
    end
    
    # this is the z update for ADMM 
    function prox_g(theta, z, u)
        
        lambda = 1e0
        
        # prox for kTRANS 
        theta1 = map(t->t[1], theta) 
        u1     = map(t->t[1], theta)
        z1     = mxcall(:TV, 1, theta1 + u1, lambda/rho)        
        
        # prox for kPL
        theta2 = map(t->t[2], theta) 
        u2     = map(t->t[2], theta)
        z2     = mxcall(:TV, 1, theta2 + u2, lambda/rho)
        
        # reconstruct z 
        z = map((k1, k2)->[k1, k2], z1, z2)
        
        return z
    end
    
    function u_step(theta, z, u)
        
        return u + theta - z
    end
    
    # initialize ADMM
    theta = map(y->theta0,              simulated_data)
    z     = map(y->theta0,              simulated_data)
    u     = map(y->zeros(size(theta0)), simulated_data)
    
    # iterate ADMM 
    num_iters = 400
    for k=1:num_iters
        theta = map(theta_step, simulated_data, theta, z, u) # this can be parallelized 
        z     = prox_g(theta, z, u)
        u     = map(u_step, theta, z, u) # this can be parallelized too 
        println("====== Iteration ======")
        println(k)
        println(norm(map(x->x[1], theta - z)))
        println(norm(map(x->x[2], theta - z)))
        # println(u)
    end
    theta = map(theta_step, simulated_data, theta, z, u)
    
    return (theta, z, u)
end

fit_parameter_map, z_fit, u_fit = ADMM(simulated_data, [0.05, 0.07])
# Out:
# 14
# 0.4759003682417861
# 954.7864488534899
# ====== Iteration ======
# 1
# 0.475900388061346
# 1790.99940728262
# ====== Iteration ======
# 2
# 0.4758999048394775
# 1563.37968417167
# ====== Iteration ======
# 3
# 0.4759005803918815
# 1469.9505582939369
# ====== Iteration ======
# 4
# 0.47590079482103165
# 1328.7478033357074
# ====== Iteration ======
# 5
# 0.47590073805684796
# 1205.2765822687375
# ====== Iteration ======
# 6
# 0.47590014720762774
# 1141.4522482445418
# ====== Iteration ======
# 7
# 0.47590026528067525
# 1090.3638983226954
# ====== Iteration ======
# LoadError: InterruptException:
# while loading In[30], in expression starting on line 65

# %%
# extract maps for individual parameters 
fit_kTRANS_map_ADMM = map(theta->theta[1], fit_parameter_map); 
fit_kPL_map_ADMM    = map(theta->theta[2], fit_parameter_map);

# extract maps for individual parameters 
# fit_kTRANS_map_ADMM = map(theta->theta[1], z_fit); 
# fit_kPL_map_ADMM    = map(theta->theta[2], z_fit);
# Out:
# LoadError: UndefVarError: fit_parameter_map not defined
# while loading In[25], in expression starting on line 2

# %%
# plot kPL map
fig = figure()
ax = fig[:add_subplot](111)
img = ax[:imshow](fit_kPL_map_ADMM')
img[:cmap] = ColorMap("summer")
img[:set_clim](vmin=0, vmax=0.15)
colorbar(img)
# title("kPL 32 x 32 ADMM")
savefig("kPL_ADMM.png")
show()
# Out:
# LoadError: UndefVarError: fit_kPL_map_ADMM not defined
# while loading In[26], in expression starting on line 4
#
#  in getindex at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:228
#  in pysequence_query at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:717
#  [inlined code] from /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:733
#  in pytype_query at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:762
#  in convert at /Users/maidens/.julia/v0.4/PyCall/src/conversions.jl:782
#  in pycall at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:363
#  in call at /Users/maidens/.julia/v0.4/PyCall/src/PyCall.jl:372
#  in close_queued_figs at /Users/maidens/.julia/v0.4/PyPlot/src/PyPlot.jl:401

# %%
simulated_data = generate_simulated_data(16, 1000);

# %%
fit_parameter_map - z_fit
# Out:
# LoadError: UndefVarError: fit_parameter_map not defined
# while loading In[28], in expression starting on line 1
